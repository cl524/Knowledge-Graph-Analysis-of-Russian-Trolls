# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd, string

from PIL import Image, ImageFont, ImageDraw

# %%
data_file3='final_result_1_p-Copy_stop_eli_3cluster.csv'
df3=pd.read_csv( data_file3, header=0, encoding="ISO-8859–1", engine='python' )

# %%
questions0=df3[df3['Group']==0]['text_P'].tolist()

ssin0=""

i=0

for ssi in questions0:
    ssin0 = ssin0 + str(ssi)
    ssin0 += " "

ssin0.strip()

wordcloud0 = WordCloud(width = 6000, height = 4000, background_color='white', max_words=1000000, collocations=False).generate(ssin0)

plt.imshow(wordcloud0, interpolation='bilinear')
plt.show()

# %%
questions1=df3[df3['Group']==1]['text_P'].tolist()

ssin1=""

i=0

for ssi in questions1:
    ssin1=ssin1+str(ssi)
    ssin1+=" "

ssin1.strip()

wordcloud1 = WordCloud(width = 6000, height = 4000, background_color='white', max_words=1000000, collocations=False).generate(ssin1)

plt.imshow(wordcloud1, interpolation='bilinear')
plt.show()

# %%
questions2=df3[df3['Group']==2]['text_P'].tolist()

ssin2=""

i=0

for ssi in questions2:
    ssin2=ssin2+str(ssi)
    ssin2+=" "

ssin2.strip()

wordcloud2 = WordCloud(width = 6000, height = 4000, background_color='white', max_words=1000000, collocations=False).generate(ssin2)

plt.imshow(wordcloud2, interpolation='bilinear')
plt.show()
